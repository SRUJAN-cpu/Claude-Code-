# %%
#Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create an API client 
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
#Helper Function
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

#Assistant msgs to history
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    # We cannot share the system prompt as None 
    # Refactored to handle the call even if the system prompt is not provided :) 

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a one sentence about Indian temples")
answer = chat(messages, temperature=0.0)
# Adujust the temperature accorinding to the creativity needed
# answer = chat(messages, temperature=1.0)

answer
# Out:
# 'Indian temples are magnificent architectural marvels that serve as sacred spaces for worship, featuring intricate carvings, towering spires, and vibrant sculptures that reflect thousands of years of rich cultural and spiritual heritage.'
